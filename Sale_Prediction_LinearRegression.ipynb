# %% [markdown]
# #Importing all the basic libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# ### Importing the dataset

# %%
df=pd.read_csv("/content/Linear Regression Sale Prediction.csv")

# %% [markdown]
# ### About the dataset

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# ...

# %% [markdown]
# > This dataset is about the SuperStore/Mart

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %% [markdown]
# >Average weight of the Item is 12.857645
#
# >Item has 4.555000	as the minimum weight
#
# >We cannot describe much about Item_Visibility
#
# >Average Item MRP is 140.992782, minimum is 31.290000	and maximum is 266.888400
#
# > We cannot describe much about Outlet_Establishment_Year

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# >Dataset has 12 columns and 8523 Rows
#
# > Memory usage of the dataset is 799.2+ KB

# %%
for  i in df.columns:
    sns.histplot(df[i],kde=True)
    plt.show()

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Handling Missing Values

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df.isnull().sum()/len(df)*100
# Out:
# Item_Identifier               0.000000
# Item_Weight                  17.165317
# Item_Fat_Content              0.000000
# Item_Visibility               0.000000
# Item_Type                     0.000000
# Item_MRP                      0.000000
# Outlet_Identifier             0.000000
# Outlet_Establishment_Year     0.000000
# Outlet_Size                  28.276428
# Outlet_Location_Type          0.000000
# Outlet_Type                   0.000000
# Item_Outlet_Sales             0.000000
# dtype: float64

# %% [markdown]
# *   Dataset does have a null values
# *   Item_Weight has 17.165317 % and Outlet_Size has 28.276428 % missing values
# *   We can fill these null values with mean and mode

# %%
df['Item_Weight'].unique()
# Out:
# array([ 9.3  ,  5.92 , 17.5  , 19.2  ,  8.93 , 10.395, 13.65 ,    nan,
#        16.2  , 11.8  , 18.5  , 15.1  , 17.6  , 16.35 ,  9.   , 13.35 ,
#        18.85 , 14.6  , 13.85 , 13.   ,  7.645, 11.65 ,  5.925, 19.25 ,
#        18.6  , 18.7  , 17.85 , 10.   ,  8.85 ,  9.8  , 13.6  , 21.35 ,
#        12.15 ,  6.42 , 19.6  , 15.85 ,  7.39 , 10.195,  9.895, 10.895,
#         7.905,  9.195,  8.365,  7.97 , 17.7  , 19.35 ,  8.645, 15.6  ,
#        18.25 ,  7.855,  7.825,  8.39 , 12.85 , 19.   ,  5.905,  7.76 ,
#        16.75 , 15.5  ,  6.055,  6.305, 20.85 , 20.75 ,  8.895, 19.7  ,
#         8.75 , 13.3  ,  8.31 , 19.75 , 17.1  , 10.5  ,  6.635, 14.15 ,
#         8.89 ,  9.1  ,  7.5  , 16.85 ,  7.485, 11.6  , 12.65 , 20.25 ,
#         8.6  , 12.6  ,  8.88 , 20.5  , 13.5  ,  7.235,  6.92 ,  8.02 ,
#        12.8  , 16.6  , 14.   , 16.   , 21.25 ,  7.365, 18.35 ,  5.465,
#         7.27 ,  6.155, 19.5  , 15.2  , 14.5  , 13.1  , 12.3  , 11.1  ,
# ...

# %%
df['Item_Weight'].value_counts()
# Out:
# 12.150    86
# 17.600    82
# 13.650    77
# 11.800    76
# 15.100    68
#           ..
# 7.275      2
# 7.685      1
# 9.420      1
# 6.520      1
# 5.400      1
# Name: Item_Weight, Length: 415, dtype: int64

# %%
df['Item_Weight'].mean()
# Out:
# 12.857645184135976

# %%
df['Item_Weight']=df['Item_Weight'].fillna(df['Item_Weight'].mean())

# %%
df['Outlet_Size'].unique()
# Out:
# array(['Medium', nan, 'High', 'Small'], dtype=object)

# %%
df['Outlet_Size'].value_counts()
# Out:
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
df['Outlet_Size']=df['Outlet_Size'].fillna(df['Outlet_Size'].mode()[0])

# %%
df.isnull().sum()/len(df)*100
# Out:
# Item_Identifier              0.0
# Item_Weight                  0.0
# Item_Fat_Content             0.0
# Item_Visibility              0.0
# Item_Type                    0.0
# Item_MRP                     0.0
# Outlet_Identifier            0.0
# Outlet_Establishment_Year    0.0
# Outlet_Size                  0.0
# Outlet_Location_Type         0.0
# Outlet_Type                  0.0
# Item_Outlet_Sales            0.0
# dtype: float64

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# *   There are no null values in the dataset.

# %% [markdown]
# **Item_Identifier**

# %%
df['Item_Identifier'].unique()
# Out:
# array(['FDA15', 'DRC01', 'FDN15', ..., 'NCF55', 'NCW30', 'NCW05'],
#       dtype=object)

# %% [markdown]
# ### Item_Identifier columns does not describe anything useful other than scanning the product while checking out hence we can drop this column

# %%
df=df.drop(["Item_Identifier"], axis=1)

# %% [markdown]
# **Item_Fat_Content**

# %%
df['Item_Fat_Content'].unique()
# Out:
# array(['Low Fat', 'Regular', 'low fat', 'LF', 'reg'], dtype=object)

# %%
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %%
df['Item_Fat_Content'].replace({'LF': 'Low Fat'},inplace=True)

# %%
df['Item_Fat_Content'].replace({'low fat': 'Low Fat'},inplace=True)

# %%
df['Item_Fat_Content'].replace({'reg': 'Regular'},inplace=True)

# %%
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %%
df['Item_Fat_Content']=df['Item_Fat_Content'].map({'Regular':1,'Low Fat':0})

# %% [markdown]
# **Item_Visibility**

# %%
df['Item_Visibility'].unique()
# Out:
# array([0.0160473 , 0.01927822, 0.01676007, ..., 0.03518627, 0.14522065,
#        0.04487828])

# %%
df['Item_Visibility'].value_counts()
# Out:
# 0.000000    526
# 0.076975      3
# 0.162462      2
# 0.076841      2
# 0.073562      2
#            ...
# 0.013957      1
# 0.110460      1
# 0.124646      1
# 0.054142      1
# 0.044878      1
# Name: Item_Visibility, Length: 7880, dtype: int64

# %% [markdown]
# ### Item_Visibility does not provide any usefull information hence we can drop the column.

# %%
df=df.drop(['Item_Visibility'], axis=1)

# %% [markdown]
# **Item_Type**

# %%
df['Item_Type'].unique()
# Out:
# array(['Dairy', 'Soft Drinks', 'Meat', 'Fruits and Vegetables',
#        'Household', 'Baking Goods', 'Snack Foods', 'Frozen Foods',
#        'Breakfast', 'Health and Hygiene', 'Hard Drinks', 'Canned',
#        'Breads', 'Starchy Foods', 'Others', 'Seafood'], dtype=object)

# %%
df['Item_Type'].value_counts()
# Out:
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64

# %%
df['Item_Type']=df['Item_Type'].map({'Fruits and Vegetables':1,'Snack Foods':2, 'Household':3, 'Frozen Foods':4, 'Dairy':5,"Canned":6, 'Baking Goods':7, 'Health and Hygiene':8, "Soft Drinks":9, "Meat":10, "Breads":11,"Hard Drinks":12, "Others":13, "Starchy Foods":14, "Breakfast":15, "Seafood":16 })

# %%
df['Item_Type'].value_counts()
# Out:
# 1     1232
# 2     1200
# 3      910
# 4      856
# 5      682
# 6      649
# 7      648
# 8      520
# 9      445
# 10     425
# 11     251
# 12     214
# 13     169
# 14     148
# 15     110
# 16      64
# Name: Item_Type, dtype: int64

# %% [markdown]
# **Outlet_Identifier**

# %%
df['Outlet_Identifier'].unique()
# Out:
# array(['OUT049', 'OUT018', 'OUT010', 'OUT013', 'OUT027', 'OUT045',
#        'OUT017', 'OUT046', 'OUT035', 'OUT019'], dtype=object)

# %%
df['Outlet_Identifier'].value_counts()
# Out:
# OUT027    935
# OUT013    932
# OUT049    930
# OUT046    930
# OUT035    930
# OUT045    929
# OUT018    928
# OUT017    926
# OUT010    555
# OUT019    528
# Name: Outlet_Identifier, dtype: int64

# %%
df['Outlet_Identifier']=df['Outlet_Identifier'].map({'OUT049': 49, 'OUT018':18, 'OUT010':10, 'OUT013':13, 'OUT027':27, 'OUT045':45,'OUT017':17, 'OUT046':46, 'OUT035':35, 'OUT019':19})

# %%
df['Outlet_Identifier'].value_counts()
# Out:
# 27    935
# 13    932
# 49    930
# 46    930
# 35    930
# 45    929
# 18    928
# 17    926
# 10    555
# 19    528
# Name: Outlet_Identifier, dtype: int64

# %% [markdown]
# **Outlet_Establishment_Year**

# %%
df['Outlet_Establishment_Year'].value_counts()
# Out:
# 1985    1463
# 1987     932
# 1999     930
# 1997     930
# 2004     930
# 2002     929
# 2009     928
# 2007     926
# 1998     555
# Name: Outlet_Establishment_Year, dtype: int64

# %%
sns.countplot(x=df['Outlet_Establishment_Year'])
# Out:
# <Axes: xlabel='Outlet_Establishment_Year', ylabel='count'>

# %%
df['Outlet_Establishment_Year']=df['Outlet_Establishment_Year'].map({1985: 1, 1987:2, 1997:3,1998:4, 1999:5, 2002:6, 2004:7,2007:8, 2009:9})

# %%
df['Outlet_Establishment_Year'].value_counts()
# Out:
# 1    1463
# 2     932
# 5     930
# 3     930
# 7     930
# 6     929
# 9     928
# 8     926
# 4     555
# Name: Outlet_Establishment_Year, dtype: int64

# %% [markdown]
# **Outlet_Size**

# %%
df['Outlet_Size'].value_counts()
# Out:
# Medium    5203
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
df['Outlet_Size'].unique()
# Out:
# array(['Medium', 'High', 'Small'], dtype=object)

# %%
df['Outlet_Size'].value_counts().plot(kind="pie", labels=['Medium', 'High', 'Small'], autopct='%.2f%%', explode = [0, 0.1, 0.1])
# Out:
# <Axes: ylabel='Outlet_Size'>

# %%
df['Outlet_Size']=df['Outlet_Size'].map({'Medium':2, 'High':3, 'Small':1})

# %%
df['Outlet_Size'].value_counts()
# Out:
# 2    5203
# 1    2388
# 3     932
# Name: Outlet_Size, dtype: int64

# %% [markdown]
# **Outlet_Location_Type**

# %%
df['Outlet_Location_Type'].unique()
# Out:
# array(['Tier 1', 'Tier 3', 'Tier 2'], dtype=object)

# %%
sns.countplot(x=df['Outlet_Location_Type'])
# Out:
# <Axes: xlabel='Outlet_Location_Type', ylabel='count'>

# %%
df['Outlet_Location_Type']=df['Outlet_Location_Type'].map({'Tier 1':1, 'Tier 3':3, 'Tier 2':2})

# %%
df['Outlet_Location_Type'].value_counts()
# Out:
# 3    3350
# 2    2785
# 1    2388
# Name: Outlet_Location_Type, dtype: int64

# %% [markdown]
# **Outlet_Type**

# %%
df['Outlet_Type'].value_counts()
# Out:
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: Outlet_Type, dtype: int64

# %%
df['Outlet_Type'].unique()
# Out:
# array(['Supermarket Type1', 'Supermarket Type2', 'Grocery Store',
#        'Supermarket Type3'], dtype=object)

# %%
df['Outlet_Type'].value_counts().plot(kind="pie", labels=['Supermarket Type1', 'Supermarket Type2', 'Grocery Store','Supermarket Type3'], autopct='%.2f%%', explode = [0, 0.1, 0.1, 0.1])
# Out:
# <Axes: ylabel='Outlet_Type'>

# %%
df['Outlet_Type']=df['Outlet_Type'].map({'Supermarket Type1':11, 'Supermarket Type2':22, 'Grocery Store':1,'Supermarket Type3':33})

# %%
df['Outlet_Type'].value_counts()
# Out:
# 11    5577
# 1     1083
# 33     935
# 22     928
# Name: Outlet_Type, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Weight                8523 non-null   float64
#  1   Item_Fat_Content           8523 non-null   int64
#  2   Item_Type                  8523 non-null   int64
#  3   Item_MRP                   8523 non-null   float64
#  4   Outlet_Identifier          8523 non-null   int64
#  5   Outlet_Establishment_Year  8523 non-null   int64
#  6   Outlet_Size                8523 non-null   int64
#  7   Outlet_Location_Type       8523 non-null   int64
#  8   Outlet_Type                8523 non-null   int64
#  9   Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(3), int64(7)
# memory usage: 666.0 KB

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# # Selecting Depending and indepedent variables

# %%
X=df.iloc[::,:-1]
X
# Out:
#       Item_Weight  Item_Fat_Content  Item_Type  Item_MRP  Outlet_Identifier  \
# 0           9.300                 0          5  249.8092                 49
# 1           5.920                 1          9   48.2692                 18
# 2          17.500                 0         10  141.6180                 49
# 3          19.200                 1          1  182.0950                 10
# 4           8.930                 0          3   53.8614                 13
# ...           ...               ...        ...       ...                ...
# 8518        6.865                 0          2  214.5218                 13
# 8519        8.380                 1          7  108.1570                 45
# 8520       10.600                 0          8   85.1224                 35
# 8521        7.210                 1          2  103.1332                 18
# 8522       14.800                 0          9   75.4670                 46
#
# ...

# %%
y=df.iloc[::,-1:]
y
# Out:
#       Item_Outlet_Sales
# 0             3735.1380
# 1              443.4228
# 2             2097.2700
# 3              732.3800
# 4              994.7052
# ...                 ...
# 8518          2778.3834
# 8519           549.2850
# 8520          1193.1136
# 8521          1845.5976
# 8522           765.6700
#
# [8523 rows x 1 columns]

# %% [markdown]
# # Splitting Data into train and test data

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2,random_state = 111)

# %%
X_train.shape, y_train.shape
# Out:
# ((6818, 9), (6818, 1))

# %%
X_test.shape, y_test.shape
# Out:
# ((1705, 9), (1705, 1))

# %% [markdown]
# # scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
se=StandardScaler()

# %%
Xtrain=se.fit_transform(X_train)
Xtest=se.fit_transform(X_test)

# %% [markdown]
# # model building

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_train_pred=lr.predict(X_train)
y_test_pred=lr.predict(X_test)

# %% [markdown]
# # Evaluation

# %%
from sklearn.metrics import r2_score, mean_squared_error

# %%
print("TRAIN")
print(np.sqrt(mean_squared_error(y_train,y_train_pred)))
print(r2_score(y_train,y_train_pred))
# Out:
# TRAIN
# 1193.3254490184804
# 0.5118683117791973

# %%
print("TEST")
print(np.sqrt(mean_squared_error(y_test,y_test_pred)))
print(r2_score(y_test,y_test_pred))
# Out:
# TEST
# 1200.2837249845672
# 0.5014592149989172

# %% [markdown]
# # cross vaildation

# %%
from sklearn.model_selection import cross_val_score

# %%
lr=LinearRegression()

# %%
scores = cross_val_score(lr, X, y, cv=5)

# %%
print("Cross-Validation Scores:", scores)
# Out:
# Cross-Validation Scores: [0.52951064 0.50105885 0.48600901 0.51033868 0.51035066]

# %%
mean_score = scores.mean()
print("Mean Score:", mean_score)
# Out:
# Mean Score: 0.5074535674438042
